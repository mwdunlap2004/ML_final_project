# %%
import pandas as pd

# %%
data = pd.read_csv('../categorized_data.csv')
data['growth_category_2'] = pd.cut(data['change_basal_area'], bins=[-0.5, 0, 0.07, 0.23, 1000], labels=['No Growth', 'Little Growth', 'Moderate Growth', 'Extreme Growth'])
data['growth_category_3'] = pd.qcut(data['change_basal_area'], 3, labels=['No/Little Growth', 'Moderate Growth', 'Extreme Growth'])
data.head().T
# Out:
#                                        0                 1                2  \
# Unnamed: 0                             1                 2                4
# site                                  AK                AK               AK
# tree                                  1A                1A               1A
# plot                                   1                 1                1
# species                         P glauca          P glauca         P glauca
# Date                          2019-01-01        2019-02-01       2019-05-01
# longitude                     -149.71571        -149.71571       -149.71571
# latitude                       68.018576         68.018576        68.018576
# da                                     1                 1                1
# mo                                     1                 2                5
# wk                                     1                 5               18
# ...

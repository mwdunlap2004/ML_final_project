# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error

import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ## Load  / Prep Data

# %%
treedf = pd.read_csv('categorized_data-2.csv')
treedf.head().T
# Out:
#                                          0                 1  \
# Unnamed: 0                               1                 2
# site                                    AK                AK
# tree                                    1A                1A
# plot                                     1                 1
# species                           P glauca          P glauca
# Date                            2019-01-01        2019-02-01
# longitude                       -149.71571        -149.71571
# latitude                         68.018576         68.018576
# da                                       1                 1
# mo                                       1                 2
# wk                                       1                 5
# yr                                    2019              2019
# average_stem_radius              10.471403         10.457236
# change_stem_radius                   0.002             0.001
# average_basal_area              344.476504        343.545055
# change_basal_area                 0.131595          0.065706
# average_soil_temperature         -4.218056           -5.6625
# average_air_pressure             89.953835         93.803372
# average_humidity                  0.840035          0.763849
# avg_solar_irradiance                   0.0          1.619657
# avg_soil_water_content            0.077694          0.073754
# freeze_flag                              1                 1
# air_pressure_cat                       low            medium
# humidity_cat                           dry               dry
# solar_cat                 (-0.001, 21.545]  (-0.001, 21.545]
# soil_moist_cat                         dry               dry
#
#                                          2                   3  \
# Unnamed: 0                               3                   4
# site                                    AK                  AK
# tree                                    1A                  1A
# plot                                     1                   1
# species                           P glauca            P glauca
# Date                            2019-03-01          2019-05-01
# longitude                       -149.71571          -149.71571
# latitude                         68.018576           68.018576
# da                                       1                   1
# mo                                       3                   5
# wk                                       9                  18
# yr                                    2019                2019
# average_stem_radius              10.463347           10.464564
# change_stem_radius                   0.001               0.005
# average_basal_area              343.946701          344.026717
# change_basal_area                 0.065744            0.328752
# average_soil_temperature         -4.797222            0.015385
# average_air_pressure             93.997761            93.79764
# average_humidity                  0.527651            0.562969
# avg_solar_irradiance                   0.0           185.70829
# avg_soil_water_content            0.074172             0.09859
# freeze_flag                              1                   0
# air_pressure_cat                    medium              medium
# humidity_cat                           dry                 dry
# solar_cat                 (-0.001, 21.545]  (53.984, 1643.066]
# soil_moist_cat                         dry                 dry
#
#                                            4
# Unnamed: 0                                 5
# site                                      AK
# tree                                      1A
# plot                                       1
# species                             P glauca
# Date                              2019-06-01
# longitude                         -149.71571
# latitude                           68.018576
# da                                         1
# mo                                         6
# wk                                        22
# yr                                      2019
# average_stem_radius                10.543083
# change_stem_radius                     0.002
# average_basal_area                 349.20878
# change_basal_area                   0.132487
# average_soil_temperature            5.043056
# average_air_pressure               92.596726
# average_humidity                    0.415431
# avg_solar_irradiance              212.142556
# avg_soil_water_content              0.289046
# freeze_flag                                0
# air_pressure_cat                         low
# humidity_cat                             dry
# solar_cat                 (53.984, 1643.066]
# soil_moist_cat                      moderate

# %%
print(treedf.columns)
# Out:
# Index(['Unnamed: 0', 'site', 'tree', 'plot', 'species', 'Date', 'longitude',
#        'latitude', 'da', 'mo', 'wk', 'yr', 'average_stem_radius',
#        'change_stem_radius', 'average_basal_area', 'change_basal_area',
#        'average_soil_temperature', 'average_air_pressure', 'average_humidity',
#        'avg_solar_irradiance', 'avg_soil_water_content', 'freeze_flag',
#        'air_pressure_cat', 'humidity_cat', 'solar_cat', 'soil_moist_cat'],
#       dtype='object')

# %%
X = treedf[["plot", "average_stem_radius", "change_stem_radius", "average_basal_area", \
           "average_soil_temperature", "average_air_pressure", "average_humidity", "avg_solar_irradiance", \
           "avg_soil_water_content", "freeze_flag"]].dropna()

# %%
corr_X = X.corr()

fig_corr_X = px.imshow(
    corr_X,
    text_auto=True,
    color_continuous_scale="RdBu_r",
    aspect="auto",
    title="Correlation Matrix of Original Variables"
)
fig_corr_X.update_layout(
    width=900,
    height=900,
)
fig_corr_X.show()

# %% [markdown]
# ## Creating Model

# %%
pca_pipe = Pipeline(steps=[
    ("scaler", StandardScaler()),
    ("pca", PCA())
])

pca_pipe.fit(X)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA())])

# %%
pca_model = pca_pipe.named_steps["pca"]
explained_var = pca_model.explained_variance_ratio_
cum_explained_var = np.cumsum(explained_var)
n_components = len(explained_var)

ev_df = pd.DataFrame({
    "PC": np.arange(1, n_components + 1),
    "ExplainedVariance": explained_var,
    "CumulativeVariance": cum_explained_var
})


fig_scree = px.line(
    ev_df, x="PC", y="ExplainedVariance",
    markers=True,
    title="Scree Plot: Proportion of Variance Explained"
)
fig_scree.show()

# %%
X_pca_scores = pca_pipe.transform(X)
pc_cols = [f"PC{i}" for i in range(1, n_components + 1)]

scores_df = pd.DataFrame(X_pca_scores, columns=pc_cols)
scores_df
# Out:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0     -0.578856  3.671677  1.229504 -0.813853  0.412969 -1.246902  1.089839
# 1     -0.958199  3.546863  1.158350 -0.920176  0.592294 -0.854217  0.023965
# 2     -0.428893  3.563171  1.966528 -0.466774  0.273561 -0.934493 -1.090766
# 3      1.342331  2.553916  2.124277 -1.161586  0.848322 -0.363860 -0.619714
# 4      2.985254  2.194364  2.372680 -1.044563  0.656703 -0.485680 -1.009387
# ...         ...       ...       ...       ...       ...       ...       ...
# 18503  1.963995  0.546041 -1.096951  1.114578 -0.997828  0.733315  0.754651
# 18504  1.290811  0.988355  0.327060  1.760546 -1.383910  1.310824 -0.352444
# 18505  2.034367  0.389727 -1.082214  1.039588 -0.885245  0.881821  0.319288
# 18506  2.142063  0.426675 -1.203617  1.032642 -0.960061  0.716423  0.638197
# 18507  2.162869  0.526255 -0.441943  1.462925 -0.988768  0.928470 -0.019432
#
#             PC8       PC9      PC10
# 0     -0.549924  0.050597  0.161804
# 1     -0.576228 -0.000800  0.199358
# 2     -0.416997  0.147610  0.192144
# 3      0.018184 -1.010310  0.167305
# 4      0.218754  0.058202  0.155511
# ...         ...       ...       ...
# 18503 -0.629796 -0.138875 -0.152045
# 18504 -0.615754  1.547356 -0.153495
# 18505 -0.272389 -0.059595 -0.150902
# 18506 -0.318387 -0.003617 -0.158919
# 18507 -0.702826 -0.100467 -0.145387
#
# [18508 rows x 10 columns]

# %%
corr_PC = scores_df.corr()

fig_corr_PC = px.imshow(
    corr_PC,
    text_auto=True,
    color_continuous_scale="RdBu_r",
    aspect="auto",
    title="Correlation Matrix of Principal Components"
)
fig_corr_PC.update_layout(
    width=800,
    height=800,
)
fig_corr_PC.show()

# %%
X_pca_scores = pca_pipe.transform(X)
pc_cols = [f"PC{i}" for i in range(1, n_components + 1)]

scores_df = pd.DataFrame(X_pca_scores, columns=pc_cols)
scores_df["Area Change"] = treedf['change_basal_area']
scores_df['species'] = treedf['species']
scores_df['plot'] = treedf['plot']
scores_df['Date'] = treedf['Date']
scores_df['average

fig_scatter = px.scatter(
    scores_df,
    x="PC2", y="PC3",
    color="Area Change",
    hover_name="species",
    hover_data="Date",
    title="Teams in PC1–PC2 Space (colored by Points)",
    color_continuous_scale="Viridis",
    width=800,
    height=800,
    opacity=0.5
)

fig_scatter.update_traces(marker=dict(size=4)) 

fig_scatter.show()

# %%
# Out:
#                       0           1           2           3           4  \
# PC1           -0.578856   -0.958199   -0.428893    1.342331    2.985254
# PC2            3.671677    3.546863    3.563171    2.553916    2.194364
# PC3            1.229504     1.15835    1.966528    2.124277     2.37268
# PC4           -0.813853   -0.920176   -0.466774   -1.161586   -1.044563
# PC5            0.412969    0.592294    0.273561    0.848322    0.656703
# PC6           -1.246902   -0.854217   -0.934493    -0.36386    -0.48568
# PC7            1.089839    0.023965   -1.090766   -0.619714   -1.009387
# PC8           -0.549924   -0.576228   -0.416997    0.018184    0.218754
# PC9            0.050597     -0.0008     0.14761    -1.01031    0.058202
# PC10           0.161804    0.199358    0.192144    0.167305    0.155511
# Area Change    0.131595    0.065706    0.065744    0.328752    0.132487
# species        P glauca    P glauca    P glauca    P glauca    P glauca
# plot                  1           1           1           1           1
# Date         2019-01-01  2019-02-01  2019-03-01  2019-05-01  2019-06-01
#
#                       5           6           7           8           9
# PC1            2.717077    2.701267    2.753083     2.29973    2.018441
# PC2            2.118888    2.037354    1.928295     2.12313    2.316101
# PC3            0.647144    1.233762    0.670167    0.763486    0.189169
# PC4           -1.468805   -1.606026   -1.878038   -1.918176   -1.733711
# PC5            0.973358    1.108208    1.270492    1.253514    1.110157
# PC6           -1.027175   -0.592069   -0.708339   -0.701913   -0.964304
# PC7           -0.100825   -0.040226    0.979834    1.134634    0.920657
# PC8             0.29833    0.806467    0.887878    1.002715   -0.213524
# PC9            0.258262    0.070869    0.191855   -0.209342   -0.098372
# PC10           0.167235    0.155526    0.133437    0.140431    0.184404
# Area Change    0.527184    0.264874    0.332836    0.395539    0.397876
# species        P glauca    P glauca    P glauca    P glauca    P glauca
# plot                  1           1           1           1           1
# Date         2016-07-01  2018-07-01  2019-07-01  2016-08-01  2018-08-01

# %%
# treedf columns
'''
['Unnamed: 0', 'site', 'tree', 'plot', 'species', 'Date', 'longitude',
       'latitude', 'da', 'mo', 'wk', 'yr', 'average_stem_radius',
       'change_stem_radius', 'average_basal_area', 'change_basal_area',
       'average_soil_temperature', 'average_air_pressure', 'average_humidity',
       'avg_solar_irradiance', 'avg_soil_water_content', 'freeze_flag',
       'air_pressure_cat', 'humidity_cat', 'solar_cat', 'soil_moist_cat']
'''
